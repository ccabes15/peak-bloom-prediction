# %%
import pandas as pd
import numpy as np

# %%
df_japan = pd.read_csv('data/japan.csv')
df_japan
# Out:
#                    location        lat        long    alt  year  bloom_date  \
# 0            Japan/Wakkanai  45.415000  141.678889   2.85  1953  1953-05-30
# 1            Japan/Wakkanai  45.415000  141.678889   2.85  1954  1954-05-27
# 2            Japan/Wakkanai  45.415000  141.678889   2.85  1955  1955-05-23
# 3            Japan/Wakkanai  45.415000  141.678889   2.85  1956  1956-05-14
# 4            Japan/Wakkanai  45.415000  141.678889   2.85  1957  1957-05-22
# ...                     ...        ...         ...    ...   ...         ...
# 6568  Japan/Minamidaitojima  25.828889  131.228611  15.30  2015  2015-02-13
# 6569  Japan/Minamidaitojima  25.828889  131.228611  15.30  2016  2016-03-01
# 6570  Japan/Minamidaitojima  25.828889  131.228611  15.30  2017  2017-02-14
# 6571  Japan/Minamidaitojima  25.828889  131.228611  15.30  2018  2018-01-29
# 6572  Japan/Minamidaitojima  25.828889  131.228611  15.30  2019  2019-02-12
#
#       bloom_doy
# 0           150
# 1           147
# ...

# %%
df_japan[df_japan['bloom_doy']<75].plot()
# Out:
# <Axes: >
